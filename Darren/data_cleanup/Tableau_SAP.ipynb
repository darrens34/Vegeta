# %%
import pandas as pd
import matplotlib as plt
from math import exp

# %matplotlib inline

# %%
df
# Out:
#           TIMESTAMP_START       TIMESTAMP_END    DTime  NETRAD    P     PA  \
# 0     2010-01-01 00:00:00 2010-01-01 00:30:00    1.021   -6.15  0.0  95.43
# 1     2010-01-01 00:30:00 2010-01-01 01:00:00    1.042   -6.27  0.0  95.41
# 2     2010-01-01 01:00:00 2010-01-01 01:30:00    1.062   -6.31  0.0  95.40
# 3     2010-01-01 01:30:00 2010-01-01 02:00:00    1.083   -6.30  0.0  95.39
# 4     2010-01-01 02:00:00 2010-01-01 02:30:00    1.104   -7.72  0.0  95.38
# 5     2010-01-01 02:30:00 2010-01-01 03:00:00    1.125  -44.22  0.0  95.35
# 6     2010-01-01 03:00:00 2010-01-01 03:30:00    1.146  -13.23  0.0  95.34
# 7     2010-01-01 03:30:00 2010-01-01 04:00:00    1.167   -5.87  0.0  95.34
# 8     2010-01-01 04:00:00 2010-01-01 04:30:00    1.188   -2.72  0.0  95.34
# 9     2010-01-01 04:30:00 2010-01-01 05:00:00    1.208   -2.44  0.0  95.34
# 10    2010-01-01 05:00:00 2010-01-01 05:30:00    1.229   -2.07  0.0  95.35
# ...

# %%
for cols in df.columns.tolist()[2:]:
    df = df[df[cols] <-9000]

# %%
df
# Out:
# Empty DataFrame
# Columns: [TIMESTAMP_START, TIMESTAMP_END, DTime, NETRAD, P, PA, PPFD_DIF, PPFD_IN, PPFD_OUT, RH, SW_IN, SW_OUT, TA, TS, TS_2, TS_3, WD, WS, CO2, FC, H, H2O, LE, SB, SC, SH, SLE, TAU, USTAR, ZL, PRI, G, SAP_FLOW]
# Index: []
#
# [0 rows x 33 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.plot()

# %%
df['es'] = df['TA'].apply(lambda x: 0.6108 * exp((17.27 * x)/(x+237.3)))

# %%
df['ea'] = 0

for i in range(len(df['es'])):
    df['ea'][i] = df['RH'][i]/1000 * df['es']
# Out:
# c:\users\darren\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\darren\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\series.py in setitem(key, value)
#     718             try:
# --> 719                 self._set_with_engine(key, value)
#     720                 return
#
# c:\users\darren\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#     777         try:
# --> 778             self.index._engine.set_value(values, key, value)
# ...

# %%
dfsap.to_csv('cleanData.csv')

# %%
df = pd.read_csv("../../data/EFDC_L2_Flx_FRHes_2010_v010_30m.txt", parse_dates=[0,1])

# %%
x = ['TIMESTAMP_START','NETRAD', 'PPFD_IN', 'SW_IN', 'SW_OUT','TA','LE','SB','G', 'SAP_FLOW']

# %%
df = df[x].set_index('TIMESTAMP_START')

# %%
dfsap = df[df["SAP_FLOW"] > 0]

# %%
dfsap.values
# Out:
# array([[Timestamp('2010-04-28 07:30:00'), Timestamp('2010-04-28 08:00:00'),
#         118.333, ..., 0.53315552, 18.965, 0.978090821285714],
#        [Timestamp('2010-04-28 08:00:00'), Timestamp('2010-04-28 08:30:00'),
#         118.354, ..., 0.535083176, 17.855, 0.81182899],
#        [Timestamp('2010-04-28 08:30:00'), Timestamp('2010-04-28 09:00:00'),
#         118.375, ..., 0.5313642470000001, 14.245, 1.4200152838888898],
#        ...,
#        [Timestamp('2010-11-15 07:30:00'), Timestamp('2010-11-15 08:00:00'),
#         319.33299999999997, ..., -9999.0, -4.275, 0.302475932875],
#        [Timestamp('2010-11-15 08:00:00'), Timestamp('2010-11-15 08:30:00'),
#         319.35400000000004, ..., -9999.0, -4.37, 0.296672351],
#        [Timestamp('2010-11-15 08:30:00'), Timestamp('2010-11-15 09:00:00'),
#         319.375, ..., -9999.0, -4.42, 0.27925269287500004]], dtype=object)

# %%
dfsap['SAP_FLOW'].groupby('hour', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-bce6d79cbec7> in <module>()
# ----> 1 dfsap['SAP_FLOW'].groupby()
#
# c:\users\darren\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4410
#    4411         if level is None and by is None:
# -> 4412             raise TypeError("You have to supply one of 'by' and 'level'")
#    4413         axis = self._get_axis_number(axis)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#
# TypeError: You have to supply one of 'by' and 'level'
